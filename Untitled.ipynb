# %%
import pandas as pd
import numpy as np

# %%
EM=pd.read_csv('estaticos_market.csv')
EM
# Out:
#         Unnamed: 0                                                 id  \
# 0                0  a6984c3ae395090e3bee8ad63c3758b110de096d5d8195...
# 1                1  6178f41ade1365e44bc2c46654c2c8c0eaae27dcb476c4...
# 2                2  4a7e5069a397f12fdd7fd57111d6dc5d3ba558958efc02...
# 3                3  3348900fe63216a439d2e5238c79ddd46ede454df7b9d8...
# 4                4  1f9bcabc9d3173c1fe769899e4fac14b053037b953a1e4...
# ...            ...                                                ...
# 462293      462293  469ee5fc984d0bb60aa2f40cda4d003d7c9b963d149ed3...
# 462294      462294  656f496e7e2fad708f0022d8ad97d2cb9344e839a5f3cb...
# 462295      462295  9b933a5cf2149d1338f00fb459d34a16b9b0f2e8d3e8e1...
# 462296      462296  84db0f17467cf4f02439e01ade57150b6ac59d9dae53ed...
# 462297      462297  3d43e934e150b86be1e67524f5ba1018b27da9ef25566d...
#
#         fl_matriz           de_natureza_juridica sg_uf  \
# 0            True  SOCIEDADE EMPRESARIA LIMITADA    RN
# ...

# %%
missing=((EM.isna().sum()/EM.shape[0]*100))
types=EM.dtypes
columns=EM.columns
tent=pd.DataFrame({'column':columns,'missing':missing,'type':types})
tent.head(50)
# Out:
#                                                                       column  \
# Unnamed: 0                                                        Unnamed: 0
# id                                                                        id
# fl_matriz                                                          fl_matriz
# de_natureza_juridica                                    de_natureza_juridica
# sg_uf                                                                  sg_uf
# natureza_juridica_macro                              natureza_juridica_macro
# de_ramo                                                              de_ramo
# setor                                                                  setor
# idade_empresa_anos                                        idade_empresa_anos
# idade_emp_cat                                                  idade_emp_cat
# fl_me                                                                  fl_me
# ...

# %%
tent2=tent.loc[tent['missing'] < 30 ]
list(tent2.column)
# Out:
# ['Unnamed: 0',
#  'id',
#  'fl_matriz',
#  'de_natureza_juridica',
#  'sg_uf',
#  'natureza_juridica_macro',
#  'de_ramo',
#  'setor',
#  'idade_empresa_anos',
#  'idade_emp_cat',
#  'fl_me',
#  'fl_sa',
#  'fl_epp',
#  'fl_mei',
#  'fl_ltda',
#  'dt_situacao',
#  'fl_st_especial',
#  'fl_email',
#  'fl_telefone',
#  'fl_rm',
#  'nm_divisao',
#  'nm_segmento',
#  'fl_spa',
#  'fl_antt',
#  'fl_veiculo',
#  'fl_optante_simples',
#  'vl_total_veiculos_pesados_grupo',
#  'vl_total_veiculos_leves_grupo',
#  'fl_optante_simei',
#  'sg_uf_matriz',
#  'de_saude_tributaria',
#  'de_saude_rescencia',
#  'nu_meses_rescencia',
#  'de_nivel_atividade',
#  'fl_simples_irregular',
#  'nm_meso_regiao',
#  'nm_micro_regiao',
#  'fl_passivel_iss',
#  'qt_socios',
#  'qt_socios_pf',
#  'qt_socios_pj',
#  'de_faixa_faturamento_estimado',
#  'de_faixa_faturamento_estimado_grupo',
#  'vl_faturamento_estimado_aux',
#  'vl_faturamento_estimado_grupo_aux',
#  'qt_filiais']

# %%
EM1= EM[tent2.column].fillna(0).select_dtypes(include=['float64','int64'])
EM1.dtypes
# Out:
# Unnamed: 0                             int64
# idade_empresa_anos                   float64
# vl_total_veiculos_pesados_grupo      float64
# vl_total_veiculos_leves_grupo        float64
# nu_meses_rescencia                   float64
# qt_socios                            float64
# qt_socios_pf                         float64
# qt_socios_pj                         float64
# vl_faturamento_estimado_aux          float64
# vl_faturamento_estimado_grupo_aux    float64
# qt_filiais                             int64
# dtype: object
